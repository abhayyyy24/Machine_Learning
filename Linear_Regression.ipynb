# %% [markdown]
# <a href="https://colab.research.google.com/github/abhayyyy24/Machine_Learning/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
x=np.array([[1],[2],[3],[4],[5]])
y=np.array([15,30,45,55,65])

# %%
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
prediction=model.predict([[2.5]])
print("predicted Score for 6 hours",prediction[0])
# Out:
# predicted Score for 6 hours 35.74999999999999

# %%
plt.scatter(x,y,color="blue",label='Actual Data')
plt.plot(x,model.predict(x),color="red",label="Regression Line")
plt.xlabel("hours studied")
plt.ylabel("exam score")
plt.legend()
plt.title("linear regression")
plt.show()
